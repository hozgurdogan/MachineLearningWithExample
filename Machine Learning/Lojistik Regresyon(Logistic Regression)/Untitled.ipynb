# %% [markdown]
# ![image.png](attachment:66507889-d0cf-4ef7-a27d-db6c81a57df8.png)

# %% [markdown]
# çıkan değeri sigmoid fonksiyonun içerisne yazarız , amacımız 0 ile 1 arasında olsun

# %% [markdown]
# ![image.png](attachment:9be914ee-6e50-4b32-8d2a-d18e9d7669dc.png)

# %% [markdown]
# ![image.png](attachment:db06373e-7f98-457a-92f8-978ef4591d1b.png)

# %% [markdown]
# ![image.png](attachment:ee15337b-c561-406f-9fab-d316889667f2.png)

# %% [markdown]
# Confusion Matrix

# %% [markdown]
# ![image.png](attachment:730581bd-fea5-41a4-b114-f3f09cfcab0d.png)

# %% [markdown]
# ![image.png](attachment:c31d558e-b5ab-42ee-849e-4b1db958bf6d.png)

# %% [markdown]
# ![image.png](attachment:f12bb97c-2e5d-4373-9292-fdafd19f7e62.png)

# %% [markdown]
# ![image.png](attachment:ee8b1b7a-d131-40bc-ba98-8eec057cd869.png)

# %% [raw]
# Duramadan treshold ları değiştirip orataya çıkan False Positive Rate  ve True Positive Rate değerlerini grafikte nokta nokta işaretleyip (Thresold 0 - 1  arasında oynucak şekilde) noktların çıkardığı eğri ne kadar çok yukarada ki alanı kaplarsa doğurluk o kadar iyi .

# %% [markdown]
# <h3>Area under Curve (AUC) </h3>

# %% [markdown]
# ![image.png](attachment:daef6553-bb96-4a82-8cbc-64281f12958c.png)
