# %% [markdown]
# ![image.png](attachment:bdc58847-2a50-45a1-8dca-d5f8fec46672.png)

# %% [markdown]
# ![image.png](attachment:c828a686-3422-4443-871b-4ff70c4b0db6.png)

# %% [markdown]
# ![image.png](attachment:81899852-e8bd-4965-9be0-401ab31c60cb.png)

# %% [markdown]
# Kaç dallanma olucağı sse  en küçük yaparken seçilen bir parametredir

# %% [markdown]
# ![image.png](attachment:612a02a3-f60a-4a5d-8dc6-c252d2ed934b.png)

# %% [markdown]
# ![image.png](attachment:5a926339-188c-471e-88ce-11f865e87842.png)

# %% [markdown]
# bölme yerine göre hata oranı değişceği için öyle bir yerden bölmeliyiz ki optimal hata oranı olsun

# %% [markdown]
# ![image.png](attachment:fb13ee40-3ab1-4752-b308-d79ef37884aa.png)

# %% [markdown]
# En az hata 94 de o yüzden 94 den bölünmeli

# %% [markdown]
# En az sse değerini veren değişken en önemli değişken olarak kabul görür ve kök düğüm olur

# %% [markdown]
# ![image.png](attachment:ebaad31b-ed72-4348-ba3b-9331055458f5.png)

# %% [markdown]
# ![image.png](attachment:1151c491-7e45-47ed-b615-74fd72714f39.png)
