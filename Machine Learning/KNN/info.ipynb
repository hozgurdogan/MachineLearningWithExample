# %% [markdown]
# ![image.png](attachment:87ebd4aa-164e-445b-975f-b3a61a795c7f.png)

# %% [markdown]
# ![image.png](attachment:26d8554c-2a16-47a9-82b2-8c6e41e97710.png)

# %% [markdown]
# ![image.png](attachment:7b8af5ef-3eed-4e54-89cd-7a7c65a50ad1.png)
